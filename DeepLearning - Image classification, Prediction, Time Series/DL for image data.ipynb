# %% [markdown]
# # MIS780 Advanced AI For Business - Assignment 2 - T2 2021
#
# ## Part B:  Deep Learning for Image Data

# %% [markdown]
# **Student Name:** Hoang Manh Nguyen
#
# **Student ID:** 219380205

# %% [markdown]
# *Markdown formats: All tables and images will be aligned to the left. (Do not remove this code)*

# %%
# %%html
# <style>table {float:left}</style>
# <style>img {float:left}</style>
# Out:
# <style>table {float:left}</style>
# <style>img {float:left}</style>

# %% [markdown]
# <hr style="height:1px;border:none;color:#333;background-color:#333;" />
#
# **Task Description**
#
# 1. Organise the Denoising Autoencoder (DAE) project structure, get data and run the notebook.
# 2. Experiment with batch and epochs for model training.
# 3. Experiment with DAE optimisers and their parameters (e.g. SGD, RMSprop, Adam, Adamax, Nadam).
# 4. Change the DAE details / architecture
# 5. Report your experimental results.
# 6. Include performance results and charts for your experiment runs.
# 7. Save the IPYNB notebook, convert it to PDF (via HTML) and submit both for assessment.
#
# **NOTE: In your reponses below, you can create multiple Markdown and Code cells to present your work where needed. Remove the *instructional text in italic* and provide your explanations to the code procedures.**
# <hr style="height:1px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# ## Table of Content
#
# 1. [Notebook Preparation](#cell_Preparation)
#
# 2. [Data Preprocessing](#cell_Preprocessing)
#
# 3. [Model Construction](#cell_model)
#
# 4. [Model Execution](#cell_execution)
#
# 5. [Experiments Report](#cell_report)

# %% [markdown]
# <a id = "cell_Preparation"></a>
# ## 1. Notebook Preparation

# %% [markdown]
# We load all required Python libraries (e.g. pandas, tensorflow, keras)
#
# Also. develop code to define some common features and functions (output display, plots) which will be used in later part

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import UpSampling2D, BatchNormalization, LeakyReLU
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import SGD, RMSprop, Adadelta, Adam, Nadam

# %%
# PLot image
def plot_images(ims, xsize=6, ysize=6, cols=1, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        if (ims.shape[-1] != 3):
            ims = ims = ims[:,:,:,0]
    f = plt.figure(figsize=(xsize, ysize))
    rows=len(ims)//cols if len(ims) % cols == 0 else len(ims)//cols + 1
    for i in range(len(ims)):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i], interpolation=None if interp else 'none')
        plt.gray()

# %%
# PLot history
# %matplotlib inline

def plot_hist(h, xsize=6, ysize=10):
    
    # Find what measurements were recorded
    meas = h.keys()
    
    # Prepare plotting
    fig_size = plt.rcParams["figure.figsize"]
    plt.rcParams["figure.figsize"] = [xsize, ysize]
    
    # Plot each measurement
    meas_list = []
    for m in meas:
        plt.plot(h[m])
        meas_list.append(m)

    # Add info to the plot
    ylab = ', '
    plt.ylabel(ylab.join(meas_list))
    plt.xlabel('epoch')
    plt.legend(meas_list) #, loc='upper left')
    plt.show()
    return

# %%
# Calculates image to image errors
def rmse_images(images1, images2):
    return math.sqrt(np.square(np.subtract(images1, images2)).mean())

def mae_images(images1, images2):
    return np.abs(np.subtract(images1, images2)).mean()

# %% [markdown]
# <a id = "cell_Preprocessing"></a>
# ## 2. Data Preprocessing

# %% [markdown]
# - Load cifar10 images from keras librabies
# - Preprocess data:
#   - convert to 8 bit
#   - split and shuffle data to create train and valid data
#   - reshape
#   - inject noise = 0.3 to both train and validatin data

# %%
from tensorflow.keras.datasets import cifar10

# Data parameters
img_rows, img_cols, img_ch = 32, 32, 3

# the data, shuffled and split between train and test sets
(x_train, _), (x_test, _) = cifar10.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step

# %%
# Reshape images for processing

x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, img_ch)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, img_ch)
input_shape = (img_rows, img_cols, img_ch)

print(x_train.shape)
print(x_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
noise_factor = 0.3
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
print(x_train_noisy.shape)
print(x_test_noisy.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# *Plot original "clean" images and noisy images.*

# %%
# plot original images 
plot_images(x_test[0:10], cols=5, xsize=10, ysize=5)

# %%
# plot noisy images 
plot_images(x_test_noisy[0:10], cols=5, xsize=10, ysize=5)

# %% [markdown]
# <a id = "cell_model"></a>
# ## 3. Model Construction

# %%
#Model 1

input_img = Input(shape=input_shape)

x = Conv2D(16, (3, 3), padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(16, (3, 3), padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (8,8,16)

x = Conv2D(16, (3, 3), padding='same')(encoded)
x = UpSampling2D((2, 2))(x)

x = Conv2D(16, (3, 3), padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 32, 32, 16)        448
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 16, 16, 16)        2320
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 8, 8, 16)          2320
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 16, 16, 16)        2320
# _________________________________________________________________
# up_sampling2d_11 (UpSampling (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 32, 32, 3)         435
# =================================================================
# Total params: 7,843
# Trainable params: 7,843
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Model 2
input_img2 = Input(shape=input_shape)

x2 = Conv2D(32, (3, 3), padding='same', activation = "relu", kernel_regularizer=regularizers.l1_l2(1e-4))(input_img2)
x2 = BatchNormalization()(x2)
x2 = MaxPooling2D((2, 2), padding='same')(x2)

x2 = Conv2D(16, (3, 3), padding='same', activation = "relu", kernel_regularizer=regularizers.l1_l2(1e-4))(x2)
x2 = BatchNormalization()(x2)
x2 = MaxPooling2D((2, 2), padding='same')(x2)

x2 = Conv2D(8, (3, 3), padding='same', activation = "relu", kernel_regularizer=regularizers.l1_l2(1e-4))(x2)
x2 = BatchNormalization()(x2)
encoded2 = MaxPooling2D((2, 2), padding='same')(x2)

x2 = Conv2D(8, (3, 3), padding='same', activation = "relu", kernel_regularizer=regularizers.l1_l2(1e-4))(encoded2)
x2 = BatchNormalization()(x2)
x2 = UpSampling2D((2, 2))(x2)

x2 = Conv2D(16, (3, 3), padding='same', activation = "relu", kernel_regularizer=regularizers.l1_l2(1e-4))(x2)
x2 = BatchNormalization()(x2)
x2 = UpSampling2D((2, 2))(x2)

x2 = Conv2D(32, (3, 3), padding='same', activation = "relu", kernel_regularizer=regularizers.l1(1e-4))(x2)
x2 = BatchNormalization()(x2)
x2 = UpSampling2D((2, 2))(x2)
decoded2 = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x2)

autoencoder2 = Model(input_img2, decoded2)
autoencoder2.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 16, 16, 16)        4624
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 16, 16, 16)        64
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 8, 8, 8)           1160
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 8, 8, 8)           32
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 4, 4, 8)           0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 4, 4, 8)           584
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 4, 4, 8)           32
# _________________________________________________________________
# up_sampling2d_12 (UpSampling (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 8, 8, 16)          1168
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 8, 8, 16)          64
# _________________________________________________________________
# up_sampling2d_13 (UpSampling (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 16, 16, 32)        4640
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# up_sampling2d_14 (UpSampling (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 32, 32, 3)         867
# =================================================================
# Total params: 14,387
# Trainable params: 14,163
# Non-trainable params: 224
# _________________________________________________________________

# %% [markdown]
# <a id = "cell_execution"></a>
# ## 4. Model Execution

# %% [markdown]
# In this section:
# - fit the models.
# -Denoise the images on the test sets and visualize the denoised images for both models.
# - Calculate the MAE (between the original and denoised images) on the test sets to compare the performance of the two models

# %% [markdown]
# **Model 1**

# %%
callbacks = [EarlyStopping(monitor='val_loss', patience=20, verbose=0)]

opt = Nadam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

#Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-07,amsgrad=False)

autoencoder.compile(optimizer=opt, loss='binary_crossentropy')
hist = autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=callbacks)
# Out:
# Epoch 1/100
# 196/196 [==============================] - 7s 32ms/step - loss: 0.5968 - val_loss: 0.5902
# Epoch 2/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5865 - val_loss: 0.5849
# Epoch 3/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5829 - val_loss: 0.5825
# Epoch 4/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5809 - val_loss: 0.5808
# Epoch 5/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5795 - val_loss: 0.5798
# Epoch 6/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5785 - val_loss: 0.5788
# Epoch 7/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5777 - val_loss: 0.5780
# Epoch 8/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5770 - val_loss: 0.5774
# Epoch 9/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5764 - val_loss: 0.5769
# Epoch 10/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5759 - val_loss: 0.5765
# Epoch 11/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5755 - val_loss: 0.5761
# Epoch 12/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5751 - val_loss: 0.5757
# Epoch 13/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5748 - val_loss: 0.5754
# Epoch 14/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5745 - val_loss: 0.5751
# Epoch 15/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5742 - val_loss: 0.5749
# Epoch 16/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5740 - val_loss: 0.5747
# Epoch 17/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5737 - val_loss: 0.5744
# Epoch 18/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5735 - val_loss: 0.5742
# Epoch 19/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5733 - val_loss: 0.5742
# Epoch 20/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5732 - val_loss: 0.5739
# Epoch 21/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5730 - val_loss: 0.5737
# Epoch 22/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5729 - val_loss: 0.5736
# Epoch 23/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5727 - val_loss: 0.5734
# Epoch 24/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5726 - val_loss: 0.5735
# Epoch 25/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5725 - val_loss: 0.5734
# Epoch 26/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5724 - val_loss: 0.5731
# Epoch 27/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5723 - val_loss: 0.5730
# Epoch 28/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5722 - val_loss: 0.5729
# Epoch 29/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5721 - val_loss: 0.5729
# Epoch 30/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5720 - val_loss: 0.5728
# Epoch 31/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5719 - val_loss: 0.5727
# Epoch 32/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5719 - val_loss: 0.5726
# Epoch 33/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5718 - val_loss: 0.5726
# Epoch 34/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5717 - val_loss: 0.5725
# Epoch 35/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5717 - val_loss: 0.5724
# Epoch 36/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5716 - val_loss: 0.5726
# Epoch 37/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5716 - val_loss: 0.5723
# Epoch 38/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5715 - val_loss: 0.5724
# Epoch 39/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5715 - val_loss: 0.5722
# Epoch 40/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5714 - val_loss: 0.5722
# Epoch 41/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5714 - val_loss: 0.5721
# Epoch 42/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5713 - val_loss: 0.5721
# Epoch 43/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5713 - val_loss: 0.5721
# Epoch 44/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5712 - val_loss: 0.5720
# Epoch 45/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5712 - val_loss: 0.5720
# Epoch 46/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5711 - val_loss: 0.5720
# Epoch 47/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5711 - val_loss: 0.5719
# Epoch 48/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5711 - val_loss: 0.5718
# Epoch 49/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5710 - val_loss: 0.5718
# Epoch 50/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5710 - val_loss: 0.5718
# Epoch 51/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5710 - val_loss: 0.5717
# Epoch 52/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5709 - val_loss: 0.5717
# Epoch 53/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5709 - val_loss: 0.5717
# Epoch 54/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5709 - val_loss: 0.5716
# Epoch 55/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5708 - val_loss: 0.5716
# Epoch 56/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5708 - val_loss: 0.5716
# Epoch 57/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5708 - val_loss: 0.5716
# Epoch 58/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5707 - val_loss: 0.5715
# Epoch 59/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5707 - val_loss: 0.5715
# Epoch 60/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5707 - val_loss: 0.5715
# Epoch 61/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5707 - val_loss: 0.5715
# Epoch 62/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5706 - val_loss: 0.5714
# Epoch 63/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5706 - val_loss: 0.5714
# Epoch 64/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5706 - val_loss: 0.5714
# Epoch 65/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5706 - val_loss: 0.5713
# Epoch 66/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5705 - val_loss: 0.5713
# Epoch 67/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5705 - val_loss: 0.5713
# Epoch 68/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5705 - val_loss: 0.5714
# Epoch 69/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5705 - val_loss: 0.5713
# Epoch 70/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5705 - val_loss: 0.5714
# Epoch 71/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5704 - val_loss: 0.5712
# Epoch 72/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5704 - val_loss: 0.5712
# Epoch 73/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5704 - val_loss: 0.5712
# Epoch 74/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5704 - val_loss: 0.5712
# Epoch 75/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5704 - val_loss: 0.5711
# Epoch 76/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5704 - val_loss: 0.5711
# Epoch 77/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5703 - val_loss: 0.5711
# Epoch 78/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5703 - val_loss: 0.5711
# Epoch 79/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5703 - val_loss: 0.5711
# Epoch 80/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5703 - val_loss: 0.5711
# Epoch 81/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5703 - val_loss: 0.5710
# Epoch 82/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5703 - val_loss: 0.5711
# Epoch 83/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5702 - val_loss: 0.5710
# Epoch 84/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5702 - val_loss: 0.5710
# Epoch 85/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5702 - val_loss: 0.5710
# Epoch 86/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5702 - val_loss: 0.5710
# Epoch 87/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5702 - val_loss: 0.5710
# Epoch 88/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5702 - val_loss: 0.5710
# Epoch 89/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5702 - val_loss: 0.5710
# Epoch 90/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5701 - val_loss: 0.5709
# Epoch 91/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5701 - val_loss: 0.5709
# Epoch 92/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5701 - val_loss: 0.5709
# Epoch 93/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5701 - val_loss: 0.5709
# Epoch 94/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5701 - val_loss: 0.5709
# Epoch 95/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5701 - val_loss: 0.5709
# Epoch 96/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5701 - val_loss: 0.5709
# Epoch 97/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5701 - val_loss: 0.5709
# Epoch 98/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5700 - val_loss: 0.5709
# Epoch 99/100
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5700 - val_loss: 0.5708
# Epoch 100/100
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5700 - val_loss: 0.5708

# %%
plot_hist(hist.history, xsize=8, ysize=5)

# %%
# encode and decode some digits from the test set
decoded_noisy_imgs = autoencoder.predict(x_test_noisy)

# %%
#Original images
plot_images(x_test[0:10], cols=5, xsize=10, ysize=5)

# %%
#Images with injected noise
plot_images(x_test_noisy[0:10], cols=5, xsize=10, ysize=5)

# %%
#Denoised images
plot_images(decoded_noisy_imgs[0:10], cols=5, xsize=10, ysize=5)

# %%
print('Original vs noisy MAE = \t', round(mae_images(x_test, x_test_noisy), 5))
print('Original vs denoised MAE = \t', round(mae_images(x_test, decoded_noisy_imgs), 5))
# Out:
# Original vs noisy MAE = 	 0.20253
# Original vs denoised MAE = 	 0.07049

# %% [markdown]
# **Model 2**

# %%
callbacks2 = [EarlyStopping(monitor='val_loss', patience=20, verbose=0)]

opt2 = Nadam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

autoencoder2.compile(optimizer=opt2, loss='binary_crossentropy')
hist2 = autoencoder2.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=callbacks2)
# Out:
# Epoch 1/100
# 391/391 [==============================] - 14s 28ms/step - loss: 1.2212 - val_loss: 1.0497
# Epoch 2/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.9214 - val_loss: 0.8407
# Epoch 3/100
# 391/391 [==============================] - 11s 29ms/step - loss: 0.7666 - val_loss: 0.7388
# Epoch 4/100
# 391/391 [==============================] - 11s 29ms/step - loss: 0.6815 - val_loss: 0.6878
# Epoch 5/100
# 391/391 [==============================] - 11s 27ms/step - loss: 0.6356 - val_loss: 0.6607
# Epoch 6/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.6119 - val_loss: 0.6364
# Epoch 7/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.6004 - val_loss: 0.6138
# Epoch 8/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5940 - val_loss: 0.6059
# Epoch 9/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5901 - val_loss: 0.5943
# Epoch 10/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5875 - val_loss: 0.5915
# Epoch 11/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5855 - val_loss: 0.5860
# Epoch 12/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5841 - val_loss: 0.5875
# Epoch 13/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5830 - val_loss: 0.5853
# Epoch 14/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5822 - val_loss: 0.5844
# Epoch 15/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5816 - val_loss: 0.5842
# Epoch 16/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5812 - val_loss: 0.5829
# Epoch 17/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5807 - val_loss: 0.5834
# Epoch 18/100
# 391/391 [==============================] - 11s 27ms/step - loss: 0.5805 - val_loss: 0.5809
# Epoch 19/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5802 - val_loss: 0.5854
# Epoch 20/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5799 - val_loss: 0.5813
# Epoch 21/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5797 - val_loss: 0.5824
# Epoch 22/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5795 - val_loss: 0.5812
# Epoch 23/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5793 - val_loss: 0.5799
# Epoch 24/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5791 - val_loss: 0.5798
# Epoch 25/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5790 - val_loss: 0.5813
# Epoch 26/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5788 - val_loss: 0.5796
# Epoch 27/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5787 - val_loss: 0.5795
# Epoch 28/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5785 - val_loss: 0.5794
# Epoch 29/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5784 - val_loss: 0.5789
# Epoch 30/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5783 - val_loss: 0.5792
# Epoch 31/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5782 - val_loss: 0.5796
# Epoch 32/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5781 - val_loss: 0.5789
# Epoch 33/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5780 - val_loss: 0.5783
# Epoch 34/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5780 - val_loss: 0.5794
# Epoch 35/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5779 - val_loss: 0.5786
# Epoch 36/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5777 - val_loss: 0.5785
# Epoch 37/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5777 - val_loss: 0.5792
# Epoch 38/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5776 - val_loss: 0.5798
# Epoch 39/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5775 - val_loss: 0.5783
# Epoch 40/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5774 - val_loss: 0.5793
# Epoch 41/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5774 - val_loss: 0.5798
# Epoch 42/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5773 - val_loss: 0.5792
# Epoch 43/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5772 - val_loss: 0.5789
# Epoch 44/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5772 - val_loss: 0.5795
# Epoch 45/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5771 - val_loss: 0.5797
# Epoch 46/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5771 - val_loss: 0.5779
# Epoch 47/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5771 - val_loss: 0.5786
# Epoch 48/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5770 - val_loss: 0.5781
# Epoch 49/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5769 - val_loss: 0.5776
# Epoch 50/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5769 - val_loss: 0.5781
# Epoch 51/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5769 - val_loss: 0.5776
# Epoch 52/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5768 - val_loss: 0.5780
# Epoch 53/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5768 - val_loss: 0.5780
# Epoch 54/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5768 - val_loss: 0.5787
# Epoch 55/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5767 - val_loss: 0.5782
# Epoch 56/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5768 - val_loss: 0.5788
# Epoch 57/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5767 - val_loss: 0.5778
# Epoch 58/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5767 - val_loss: 0.5788
# Epoch 59/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5766 - val_loss: 0.5783
# Epoch 60/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5767 - val_loss: 0.5779
# Epoch 61/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5766 - val_loss: 0.5775
# Epoch 62/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5766 - val_loss: 0.5778
# Epoch 63/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5766 - val_loss: 0.5774
# Epoch 64/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5766 - val_loss: 0.5788
# Epoch 65/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5766 - val_loss: 0.5773
# Epoch 66/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5765 - val_loss: 0.5791
# Epoch 67/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5765 - val_loss: 0.5772
# Epoch 68/100
# 391/391 [==============================] - 11s 27ms/step - loss: 0.5765 - val_loss: 0.5776
# Epoch 69/100
# 391/391 [==============================] - 11s 27ms/step - loss: 0.5765 - val_loss: 0.5777
# Epoch 70/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5765 - val_loss: 0.5782
# Epoch 71/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5764 - val_loss: 0.5779
# Epoch 72/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5764 - val_loss: 0.5777
# Epoch 73/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5764 - val_loss: 0.5779
# Epoch 74/100
# 391/391 [==============================] - 11s 27ms/step - loss: 0.5764 - val_loss: 0.5775
# Epoch 75/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5764 - val_loss: 0.5770
# Epoch 76/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5763 - val_loss: 0.5793
# Epoch 77/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5763 - val_loss: 0.5783
# Epoch 78/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5763 - val_loss: 0.5777
# Epoch 79/100
# 391/391 [==============================] - 11s 27ms/step - loss: 0.5763 - val_loss: 0.5789
# Epoch 80/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5762 - val_loss: 0.5771
# Epoch 81/100
# 391/391 [==============================] - 11s 27ms/step - loss: 0.5762 - val_loss: 0.5770
# Epoch 82/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5762 - val_loss: 0.5772
# Epoch 83/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5762 - val_loss: 0.5779
# Epoch 84/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5761 - val_loss: 0.5795
# Epoch 85/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5761 - val_loss: 0.5797
# Epoch 86/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5761 - val_loss: 0.5766
# Epoch 87/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5761 - val_loss: 0.5780
# Epoch 88/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5761 - val_loss: 0.5771
# Epoch 89/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5761 - val_loss: 0.5774
# Epoch 90/100
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5760 - val_loss: 0.5774
# Epoch 91/100
# 391/391 [==============================] - 11s 27ms/step - loss: 0.5760 - val_loss: 0.5782
# Epoch 92/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5760 - val_loss: 0.5773
# Epoch 93/100
# 391/391 [==============================] - 11s 27ms/step - loss: 0.5760 - val_loss: 0.5776
# Epoch 94/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5760 - val_loss: 0.5796
# Epoch 95/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5760 - val_loss: 0.5784
# Epoch 96/100
# 391/391 [==============================] - 11s 27ms/step - loss: 0.5760 - val_loss: 0.5773
# Epoch 97/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5760 - val_loss: 0.5768
# Epoch 98/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5759 - val_loss: 0.5788
# Epoch 99/100
# 391/391 [==============================] - 11s 27ms/step - loss: 0.5759 - val_loss: 0.5774
# Epoch 100/100
# 391/391 [==============================] - 10s 27ms/step - loss: 0.5759 - val_loss: 0.5775

# %%
plot_hist(hist2.history, xsize=8, ysize=5)

# %%
# encode and decode some digits from the test set
decoded_noisy_imgs2 = autoencoder2.predict(x_test_noisy)

# %%
#Original images
plot_images(x_test[0:10], cols=5, xsize=10, ysize=5)

# %%
#Images with injected noise
plot_images(x_test_noisy[0:10], cols=5, xsize=10, ysize=5)

# %%
#Denoised images
plot_images(decoded_noisy_imgs2[0:10], cols=5, xsize=10, ysize=5)

# %%
print('Original vs noisy MAE = \t', round(mae_images(x_test, x_test_noisy), 5))
print('Original vs denoised MAE = \t', round(mae_images(x_test, decoded_noisy_imgs2), 5))
# Out:
# Original vs noisy MAE = 	 0.20253
# Original vs denoised MAE = 	 0.07741

# %% [markdown]
# <a id = "cell_report"></a>
# ## 5. Experiments Report

# %% [markdown]
# **Summary of experimental results**
#
#
# | Model# |  Original vs noisy MAE | Original vs denoised MAE |
# | :-: | -: | -: |
# | 1 | 0.20253 | 0.07049 |  |
# | 2 | 0.20253 | 0.07741  |   |
#
# Model 2 results < Model 1 result

# %% [markdown]
# **Model 1**: 2 encode layer, 2 decode layer, no activation function, no regularizer
#
# -> graph shows a very slight overtraining

# %% [markdown]
# **Model 2** 3 encode layer, 3 decode layer, activation "relu" and regualarizer l1,l2, also use BatchNormalization

# %% [markdown]
# As Model 2 are devopled with more advanced features to control the training, prevent overtraining and improve performance, Model 2 is the best model even Model 2 result is lower
